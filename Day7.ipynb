# %% [markdown]
# <a href="https://colab.research.google.com/github/PraveenAnanth5451/BootCamp/blob/main/Day7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Task 1**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(-1, 784).astype('float32') / 255.0
x_test = x_test.reshape(-1, 784).astype('float32') / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

model = keras.Sequential([
    layers.Input(shape=(784,)),
    layers.Dense(10, activation='softmax')
])

model.compile(optimizer='RMSprop', loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=10, batch_size=32)
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8340 - loss: 0.6570 - val_accuracy: 0.9148 - val_loss: 0.3057
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9137 - loss: 0.3072 - val_accuracy: 0.9200 - val_loss: 0.2880
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9201 - loss: 0.2889 - val_accuracy: 0.9223 - val_loss: 0.2839
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9227 - loss: 0.2843 - val_accuracy: 0.9224 - val_loss: 0.2793
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9232 - loss: 0.2791 - val_accuracy: 0.9232 - val_loss: 0.2814
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9259 - loss: 0.2752 - val_accuracy: 0.9260 - val_loss: 0.2798
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9281 - loss: 0.2720 - val_accuracy: 0.9266 - val_loss: 0.2777
# ...

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss Curve')

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy Curve')
plt.show()

# %% [markdown]
# # **Task 2**

# %%
def create_model():
    model = keras.Sequential([
        layers.Input(shape=(784,)),
        layers.Dense(10, activation='softmax')
    ])
    model.compile(optimizer='RMSprop', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

batch_sizes = [1000, 2000]
histories = {}

# %%
for i, batch_size in enumerate(batch_sizes):
    model = create_model()
    histories[batch_size] = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=10, batch_size=batch_size, verbose=0)

    plt.subplot(2, 2, i + 1)
    plt.plot(histories[batch_size].history['loss'], label=f'Training Loss (Batch {batch_size})')
    plt.plot(histories[batch_size].history['val_loss'], label=f'Validation Loss (Batch {batch_size})')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.title(f'Loss Curve (Batch {batch_size})')

    plt.subplot(2, 2, i + 3)
    plt.plot(histories[batch_size].history['accuracy'], label=f'Training Accuracy (Batch {batch_size})')
    plt.plot(histories[batch_size].history['val_accuracy'], label=f'Validation Accuracy (Batch {batch_size})')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title(f'Accuracy Curve (Batch {batch_size})')

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Task 4**

# %%
def create_model():
    model = keras.Sequential([
        layers.Input(shape=(784,)),
        layers.Dense(50, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.05), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

history = create_model().fit(x_train, y_train, validation_data=(x_test, y_test), epochs=20, batch_size=32)
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8008 - loss: 0.7291 - val_accuracy: 0.7545 - val_loss: 0.7972
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8684 - loss: 0.5671 - val_accuracy: 0.8802 - val_loss: 0.5523
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8775 - loss: 0.5299 - val_accuracy: 0.8735 - val_loss: 0.5301
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8803 - loss: 0.5243 - val_accuracy: 0.8671 - val_loss: 0.5392
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8774 - loss: 0.5326 - val_accuracy: 0.8730 - val_loss: 0.5983
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.8752 - loss: 0.5442 - val_accuracy: 0.8877 - val_loss: 0.6471
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8743 - loss: 0.5611 - val_accuracy: 0.8871 - val_loss: 0.5984
# Epoch 8/20
# ...

# %%
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss Curve')

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy Curve')

plt.show()

# %% [markdown]
# ### **Task 3**

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adadelta, Adam

# Load dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
y_train, y_test = to_categorical(y_train, 10), to_categorical(y_test, 10)


def create_model():
    model = Sequential([
        Flatten(input_shape=(28, 28)),
        Dense(10, activation='softmax')
    ])
    return model


model_adadelta = create_model()
model_adadelta.compile(optimizer=Adadelta(learning_rate=0.01), loss='categorical_crossentropy', metrics=['accuracy'])
history_adadelta = model_adadelta.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=20, verbose=1)

model_adam = create_model()
model_adam.compile(optimizer=Adam(learning_rate=0.05), loss='categorical_crossentropy', metrics=['accuracy'])
history_adam = model_adam.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=20, verbose=1)


fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].plot(history_adadelta.history['loss'], label='AdaDelta')
axes[0].plot(history_adam.history['loss'], label='Adam')
axes[0].set_title('Loss Curve')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].legend()

axes[1].plot(history_adadelta.history['accuracy'], label='AdaDelta')
axes[1].plot(history_adam.history['accuracy'], label='Adam')
axes[1].set_title('Accuracy Curve')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Accuracy')
axes[1].legend()

plt.show()

final_acc_adadelta = history_adadelta.history['accuracy'][-1]
final_acc_adam = history_adam.history['accuracy'][-1]
print(f"Final Accuracy - AdaDelta: {final_acc_adadelta:.4f}, Adam: {final_acc_adam:.4f}")
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.2044 - loss: 2.2036 - val_accuracy: 0.5599 - val_loss: 1.7025
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6313 - loss: 1.5893 - val_accuracy: 0.7593 - val_loss: 1.2689
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7637 - loss: 1.2151 - val_accuracy: 0.8046 - val_loss: 1.0134
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7997 - loss: 0.9932 - val_accuracy: 0.8256 - val_loss: 0.8603
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8185 - loss: 0.8561 - val_accuracy: 0.8409 - val_loss: 0.7608
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8323 - loss: 0.7650 - val_accuracy: 0.8514 - val_loss: 0.6931
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8406 - loss: 0.7084 - val_accuracy: 0.8595 - val_loss: 0.6426
# Epoch 8/20
# ...

# %% [markdown]
# ### **Task 5**

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
y_train, y_test = to_categorical(y_train, 10), to_categorical(y_test, 10)

def create_model():
    model = Sequential([
        Flatten(input_shape=(28, 28)),
        Dense(50, activation='relu'),
        Dropout(0.2),
        Dense(10, activation='softmax')
    ])
    return model

model = create_model()
model.compile(optimizer=Adam(learning_rate=0.05), loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=20, batch_size=32, verbose=1)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].plot(history.history['loss'], label='Training Loss')
axes[0].plot(history.history['val_loss'], label='Validation Loss')
axes[0].set_title('Loss Curve')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].legend()

axes[1].plot(history.history['accuracy'], label='Training Accuracy')
axes[1].plot(history.history['val_accuracy'], label='Validation Accuracy')
axes[1].set_title('Accuracy Curve')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Accuracy')
axes[1].legend()

plt.show()

final_acc_train = history.history['accuracy'][-1]
final_acc_val = history.history['val_accuracy'][-1]
print(f"Final Training Accuracy: {final_acc_train:.4f}, Final Validation Accuracy: {final_acc_val:.4f}")
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7347 - loss: 0.9331 - val_accuracy: 0.7848 - val_loss: 0.7793
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7316 - loss: 0.9171 - val_accuracy: 0.8631 - val_loss: 0.5951
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7458 - loss: 0.8765 - val_accuracy: 0.8479 - val_loss: 0.6098
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7382 - loss: 0.8917 - val_accuracy: 0.8257 - val_loss: 0.6634
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7440 - loss: 0.8863 - val_accuracy: 0.8459 - val_loss: 0.5840
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7312 - loss: 0.9034 - val_accuracy: 0.8152 - val_loss: 0.7457
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7222 - loss: 0.9463 - val_accuracy: 0.8346 - val_loss: 0.7211
# Epoch 8/20
# ...
